# %%
# !pip install -q streamlit pyngrok google-generativeai

# %%
# %%writefile app.py
import streamlit as st
import google.generativeai as genai
# Configure Gemini API
genai.configure(api_key="AQ.Ab8RN6L4xn4Z5nXPZc9PrrYgundvsbuYkuaTzCnm7geCO2qoBQ")
model = genai.GenerativeModel("gemini-2.5-flash")
st.set_page_config(page_title="AI Learning Buddy", page_icon="🎓🎓")
st.title("🎓🎓 AI Learning Buddy")
topic = st.text_input("End to end machine learning")
option = st.selectbox(
    "Choose Activity",
    [
        "Explain Concept",
        "Real-Life Example",
        "Generate Quiz",
        "Ask Anything"
    ]
)

if st.button("Generate"):
    if topic == "":
        st.warning("Please enter a topic.")
    else:
        if option == "Explain Concept":
            prompt = f"Explain {topic} in simple language for a beginner."
        elif option == "Real-Life Example":
            prompt = f"Give one simple real-life example of {topic}."
        elif option == "Generate Quiz":
            prompt = f"Create 5 MCQs on {topic} with answers."
        else:
            prompt = topic
        response = model.generate_content(prompt)
        st.write(response.text)
# Out:
# Overwriting app.py

# %%
# !nohup streamlit run app.py --server.port 8501  &
# Out:
# nohup: appending output to 'nohup.out'

# %%
import time
time.sleep(10)

# %%
# !fuser -k 8501/tcp
# Out:
# 8501/tcp:            15615

# %%
import time
time.sleep(5) # Give the port a few seconds to free up

# %%
# !cat nohup.out
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-07-20 14:55:48.987 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.243.192.222:8501
#
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-07-20 15:57:13.884 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.243.192.222:8501

# %%
# !pip install -q pyngrok

# %%
from pyngrok import ngrok
ngrok.set_auth_token("3GPcyTSGuiBQaRabBgOyMVW4fvv_D1aL7rY4LYXpPLiCucUw")

# %%
public_url =ngrok.connect(8501)

print(public_url)
# Out:
# NgrokTunnel: "https://gush-goes-rotting.ngrok-free.dev" -> "http://localhost:8501"
